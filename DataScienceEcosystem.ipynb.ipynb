# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# **Objetivos:**
#
# * Introducion a los cuadernos Jupyter
# * Kernels jupyter
# * Arquitetura de Jupyter

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los científicos de datos son:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
#
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Plotly

# %% [markdown]
# |Herramientas de Ciencia de Datos|
# |----------------------|
# |  Python  |
# | Jupyter Notebook  |
# | Git              |
# | Git Hub|

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python

# %% [markdown]
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros  (3*4)+5

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# Para convertir minutos en horas hacemos una division ejemplo: 200 minutos / 60 segundos

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor

# %% [markdown]
# Jessica Batista Augusto
